# %% [markdown]
# ### Data Pipeline Tools and Technologies
#
# ![Screenshot_178.png](attachment:Screenshot_178.png)
# ![Screenshot_179.png](attachment:Screenshot_179.png)
# ![Screenshot_180.png](attachment:Screenshot_180.png)
# ![Screenshot_182.png](attachment:Screenshot_182.png)
# ![Screenshot_183.png](attachment:Screenshot_183.png)
# ![Screenshot_184.png](attachment:Screenshot_184.png)
# ![Screenshot_185.png](attachment:Screenshot_185.png)
